# %% [markdown]
# ## Final

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# read the file into a dataframe
df = pd.read_csv("final.csv")
# df = df.rename(columns={ df.columns[8]: "GDP_per_year" })
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %%
# get column name by column index
colname = df.columns[9]
print (colname)
# Out:
#  gdp_for_year ($)

# %%
# check if there is any nan value in this dataframe
print("Country: ", df["country"].isnull().sum())
print("Year: ", df["year"].isnull().sum())
print("Sex: ", df["sex"].isnull().sum())
print("Age: ", df["age"].isnull().sum())
print("Suicides_no: ", df["suicides_no"].isnull().sum())
print("Population: ", df["population"].isnull().sum())
# Out:
# Country:  0
# Year:  0
# Sex:  0
# Age:  0
# Suicides_no:  0
# Population:  0

# %%
new_df = df.drop(["country-year", "generation"], axis=1)
# new_df.rename(columns={'gdp_for_year ($)': 'GDP per year'}, inplace=True)

# %%
new_df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %%
# new_df['gdp_for_year (average$)'] = new_df['population'] / new_df['gdp_for_year ($)']
# new_df['income level'] = np.where(new_df['gdp_for_year (average$)']>=12056, 'high-income', 'low-income')

# %%
hdi_df = new_df[new_df['HDI for year'].notnull()]
hdi_df.to_csv("noNan_in_HDI.csv", index=False) # not write row names (index)
hdi_df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 72        Albania  1995    male  25-34 years           13      232900
# 73        Albania  1995    male  55-74 years            9      178000
# 74        Albania  1995  female    75+ years            2       40800
# 75        Albania  1995  female  15-24 years           13      283500
# 76        Albania  1995    male  15-24 years           11      241200
# 77        Albania  1995    male    75+ years            1       25100
# 78        Albania  1995    male  35-54 years           14      375900
# 79        Albania  1995  female  25-34 years            7      264000
# 80        Albania  1995  female  35-54 years            8      356400
# 81        Albania  1995    male   5-14 years            6      376500
# 82        Albania  1995  female  55-74 years            2      180400
# 83        Albania  1995  female   5-14 years            2      348700
# ...

# %%
new_df[new_df['HDI for year'].isnull()]
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 10 columns):
# country               27820 non-null object
# year                  27820 non-null int64
# sex                   27820 non-null object
# age                   27820 non-null object
# suicides_no           27820 non-null int64
# population            27820 non-null int64
# suicides/100k pop     27820 non-null float64
# HDI for year          8364 non-null float64
#  gdp_for_year ($)     27820 non-null object
# gdp_per_capita ($)    27820 non-null int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 2.1+ MB

# %%
# check data
new_df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# ...

# %%
# check missing values
new_df.isnull().sum()
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# dtype: int64

# %%
# check age range
sorted(new_df['age'].unique())
# Out:
# ['15-24 years',
#  '25-34 years',
#  '35-54 years',
#  '5-14 years',
#  '55-74 years',
#  '75+ years']

# %%
# check gender range
sorted(new_df['sex'].unique())
# Out:
# ['female', 'male']

# %%
# check distribution of missing values across different countries
new_df[new_df['HDI for year'].isnull()].country.value_counts()
# new_df[new_df.age.isnull()].country.value_counts()
# Out:
# Republic of Korea        372
# Puerto Rico              372
# Russian Federation       324
# Antigua and Barbuda      288
# Turkmenistan             288
# Suriname                 264
# Australia                264
# Singapore                264
# Iceland                  262
# Austria                  262
# Mauritius                262
# Netherlands              262
# Spain                    252
# United Kingdom           252
# Greece                   252
# Chile                    252
# Belgium                  252
# Israel                   252
# Mexico                   252
# Luxembourg               252
# Norway                   252
# Saint Lucia              252
# Malta                    252
# Guatemala                252
# Ecuador                  252
# Colombia                 252
# Italy                    252
# Brazil                   252
# Japan                    252
# Argentina                252
#                         ...
# Aruba                    168
# ...

# %%
# %matplotlib inline

bp = new_df.boxplot()

# %% [markdown]
# ### Boxplot
# The first thing to notice is that 'population' has many outliers.
#
# However, plotting all data together might not be right because of teh different ranges of attributes. Therefore, we look at one attribute at a time instead.

# %%
bp = new_df.boxplot(column='population')

# %%
# Sometimes you have to force display of outliers:
bp = plt.boxplot(new_df.population, 0, 'ro') # red circle

# %%
new_df.to_csv("data_wrangling.csv", index=False) # not write row names (index)

# %%
dw_df = pd.read_csv("data_wrangling.csv")
dw_df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %% [markdown]
# ## HDI

# %%
HDI_df = pd.read_csv("Human_Development_Index(HDI).csv", encoding = "ISO-8859-1") #encoding = 'utf-8')
HDI_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                              Human Development Index (HDI)
# HDI Rank Country                                    1990.000 NaN 1991.000 NaN 1992.000 NaN 1993.000 NaN 1994.000 NaN 1995.000 NaN 1996.000 NaN 1997.000 NaN 1998.000 NaN 1999.000 NaN 2000.000 NaN 2001.000 NaN 2002.000 NaN 2003.000 NaN 2004.000 NaN 2005.000 NaN 2006.000 NaN 2007.000 NaN 2008.000 NaN 2009.000 NaN 2010.000 NaN 2011.000 NaN 2012.000 NaN 2013.000 NaN 2014.000 NaN 2015.000 NaN 2016.000 NaN 2017.000                            NaN
# ...

# %% [markdown]
# ## Suicide (country, year, sex, age, count of suicides, population)

# %%
suicide_df = pd.read_csv("who_suicide_statistics.csv", encoding = "ISO-8859-1") #encoding = 'utf-8')
suicide_df
# Out:
#                     country  year     sex          age  suicides_no  \
# 0                   Albania  1985  female  15-24 years          NaN
# 1                   Albania  1985  female  25-34 years          NaN
# 2                   Albania  1985  female  35-54 years          NaN
# 3                   Albania  1985  female   5-14 years          NaN
# 4                   Albania  1985  female  55-74 years          NaN
# 5                   Albania  1985  female    75+ years          NaN
# 6                   Albania  1985    male  15-24 years          NaN
# 7                   Albania  1985    male  25-34 years          NaN
# 8                   Albania  1985    male  35-54 years          NaN
# 9                   Albania  1985    male   5-14 years          NaN
# 10                  Albania  1985    male  55-74 years          NaN
# 11                  Albania  1985    male    75+ years          NaN
# 12                  Albania  1986  female  15-24 years          NaN
# ...
